# %%
import pandas as pd
import numpy as np
from pulp import LpMinimize, LpProblem, LpVariable, lpSum, LpBinary, LpStatus

def optimize_warehouse_storage(data_path):
    pd.options.display.max_rows = None  # Set to None to display all rows
    pd.options.display.max_columns = None  # Set to display all columns
    pd.set_option('display.expand_frame_repr', False)  # Prevent DataFrame wrapping

    # Load and preprocess data
    df = pd.read_csv(data_path)
    
    # Extract key parameters
    num_skus = len(df['s'].unique())
    num_locations = len(df['l'].unique())
    max_bins = int(df['ni'].dropna().max())
    
    # Create mapping dictionaries for locations and SKUs
    location_map = {loc: idx for idx, loc in enumerate(df['l'].unique())}
    sku_map = {sku: idx for idx, sku in enumerate(df['s'].unique())}
    
    # Initialize optimization problem
    prob = LpProblem("Warehouse_Optimization", LpMinimize)
    
    # Decision variables
    y = LpVariable.dicts("storage_assignment",
                         ((s, i, t) for s in range(num_skus)
                          for i in range(num_locations)
                          for t in range(int(max_bins))),
                         cat=LpBinary)
    
    z_pick = LpVariable.dicts("picking_distance", range(len(df)), lowBound=0)
    z_replenish = LpVariable.dicts("replenish_distance", range(len(df)), lowBound=0)
    
    # Objective function: Minimize total distance (picking + replenishment)
    avg_walking_speed = 1.0  # meters per second
    prob += (lpSum(z_pick[k] + z_replenish[k] for k in range(len(df))) * 
            (1/avg_walking_speed))  # Convert to time
    
    # Constraints
    for s in range(num_skus):
        prob += lpSum(y[s,i,t] for i in range(num_locations) 
                      for t in range(int(max_bins))) == 1

    for i in range(num_locations):
        prob += lpSum(y[s,i,t] * t for s in range(num_skus)
                      for t in range(int(max_bins))) <= df['ni'].iloc[i]

    for k in range(len(df)):
        sku_idx = sku_map[df['s'].iloc[k]]
        prob += z_pick[k] >= lpSum(2 * df['hi'].iloc[i] * y[sku_idx,i,t]
                                   for i in range(num_locations)
                                   for t in range(int(max_bins)))

        prob += z_replenish[k] >= lpSum(
            2 * df['r'].iloc[i] * np.ceil(df['ds'].iloc[k] / (df['qs'].iloc[k] * t)) * y[sku_idx,i,t]
            for i in range(num_locations)
            for t in range(int(max_bins)) if df['qs'].iloc[k] * t > 0)

    # Solve the problem
    prob.solve()

    # Process results
    results = []
    if LpStatus[prob.status] == 'Optimal':
        for s in range(num_skus):
            for i in range(num_locations):
                for t in range(int(max_bins)):
                    if y[s,i,t].varValue > 0.5:
                        results.append({
                            'SKU': list(sku_map.keys())[s],
                            'Location': list(location_map.keys())[i],
                            'Bin': t + 1,
                            'Distance_Pick': z_pick[s].varValue,
                            'Distance_Replenish': z_replenish[s].varValue,
                            'Time_Pick': z_pick[s].varValue / avg_walking_speed,
                            'Time_Replenish': z_replenish[s].varValue / avg_walking_speed
                        })
        
        results_df = pd.DataFrame(results)
        print(results_df)
        total_distance = sum(z_pick[k].varValue + z_replenish[k].varValue for k in range(len(df)))
        total_time = total_distance / avg_walking_speed
        print(f"\nTotal Distance: {total_distance:.2f} meters")
        print(f"Total Time: {total_time:.2f} seconds")
    else:
        print("No optimal solution found")

# Usage example
if __name__ == "__main__":
    optimize_warehouse_storage('Book12.csv')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /usr/local/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/f8/sfvcnkwx62g3v6xnb7x8g7580000gn/T/b6c340ce8aa546ac8955f06c5697c92e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/f8/sfvcnkwx62g3v6xnb7x8g7580000gn/T/b6c340ce8aa546ac8955f06c5697c92e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 254 COLUMNS
# At line 31055 RHS
# At line 31305 BOUNDS
# At line 36850 ENDATA
# Problem MODEL has 249 rows, 5698 columns and 19558 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 677.6 - 0.05 seconds
# Cgl0004I processed model has 249 rows, 3542 columns (3388 integer (3388 of which binary)) and 13398 elements
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 677.6
# Cbc0038I Relaxing continuous gives 677.6
# Cbc0038I Before mini branch and bound, 3388 integers at bound fixed and 77 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.17 seconds)
# Cbc0038I After 0.17 seconds - Feasibility pump exiting with objective of 677.6 - took 0.01 seconds
# Cbc0012I Integer solution of 677.6 found by feasibility pump after 0 iterations and 0 nodes (0.18 seconds)
# Cbc0001I Search completed - best objective 677.5999999999996, took 0 iterations and 0 nodes (0.18 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 677.6 to 677.6
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                677.60000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.14
# Time (Wallclock seconds):       0.20
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.16   (Wallclock seconds):       0.25
#
#                                 SKU       Location  Bin  Distance_Pick  Distance_Replenish  Time_Pick  Time_Replenish
# 0                    Spidol Snowman  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 1                    Puplen Snowman  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 2                     Pulpen faster  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 3                   Pulpen Standard  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 4                      Spidol Warna  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 5                       USB Vention  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 6                        USB Ugreen  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 7             Sampul Plastik Bening  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 8                      Sampul Putih  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 9           Spray Pengharum Ruangan  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 10        Pengharum Ruangan Gantung  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 11                Kit Kabel & Remot  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 12             Buku Akuntansi Besar  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 13             Buku Akuntansi Kecil  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 14   Buku Akuntansi Persegi Panjang  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 15                  Gantungan Kunci  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 16              Correction Pen Cair  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 17                  Correction Tape  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 18                           Pensil  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 19                     Stabilo Boss  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 20                           Amplop  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 21            Penghapus Papan Tulis  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 22                    Tinta Printer  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 23                   Stappler Besar  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 24                  Stappler Sedang  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 25              Refill Tinta Spidol  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 26                   Tape Dispenser  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 27                 Pembolong Kertas  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 28                          Gunting  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 29                        Buku Note  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 30                      Memory Card  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 31                  Magic Twist Tie  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 32                        Stamp Pad  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 33                      Sticky Note  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 34                              RAM  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 35                      Kertas Foto  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 36                    Tissue Wipers  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 37                     Map Business  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 38                   Lem Fox Sedang  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 39                          Lem Uhu  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 40          Permanent Mounting Tape  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 41                       Glue Stick  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 42                    Lem Fox Besar  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 43                    Clip Binder 6  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 44                  Clip Binder 200  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 45                  Clip Binder 111  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 46                  Clip Binder 107  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 47                  Clip Binder 155  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 48                       USB Type C  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 49                  Isi Stappler 10  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 50                   Isi Stappler 3  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 51                        Mouse Pad  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 52                       Double Tip  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 53                     Lakban Hitam  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 54                     Lakban Putih  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 55                     Lakban Merah  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 56                    Lakban Kuning  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 57                   Lakban Cokelat  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 58                           Panfix  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 59                HDMI Card Vention  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 60                             Paku  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 61                   TP Link Router  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 62           Pembolong Kertas BOSCH  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 63                    HDMI Type 10M  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 64         Laminating Pouch Film A4  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 65                         Pembatas  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 66                        Map Tel-U  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 67                         Keyboard  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 68                         Harddisk  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 69  Baterai Alkaline AA (Box Besar)  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 70             Baterai Alkaline AAA  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 71  Baterai Alkaline AA (Box Kecil)  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 72                     Power Supply  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 73                     Amplop Tel-U  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 74                 Map Office Warna  Rak E Level 2    1            8.8                 0.0        8.8             0.0
# 75                    Lampu Panjang  Rak E Level 1    1            8.8                 0.0        8.8             0.0
# 76                      Water Based  Rak E Level 1    1            8.8                 0.0        8.8             0.0
#
# Total Distance: 677.60 meters
# Total Time: 677.60 seconds

# %%
import pandas as pd
import numpy as np
from pulp import LpMinimize, LpProblem, LpVariable, lpSum, LpBinary, LpStatus

def optimize_warehouse_storage(data_path):
    pd.options.display.max_rows = None  # Display all rows
    pd.options.display.max_columns = None  # Display all columns
    pd.set_option('display.expand_frame_repr', False)  # Prevent DataFrame wrapping

    # Load and preprocess data
    df = pd.read_csv(data_path)
    
    # Assuming 'order_frequency' needs to be calculated from another data source or column
    # Example: df['order_frequency'] = calculate_order_frequency(df)
    # For now, simulate this frequency as a random integer (placeholder)
    df['order_frequency'] = np.random.randint(1, 100, size=len(df))

    # Sort SKUs by their frequency of appearance in descending order
    df.sort_values('order_frequency', ascending=False, inplace=True)

    # Extract key parameters
    skus = df['s'].unique()
    locations = df['l'].unique()
    max_bins = {location: df[df['l'] == location]['ni'].max() for location in locations}

    # Initialize the MILP problem
    prob = LpProblem("Warehouse_Optimization", LpMinimize)
    
    # Decision variables
    # y[s, i, t] is 1 if SKU s is assigned to bin t at location i
    y = LpVariable.dicts("bin_assignment",
                         ((s, i, t) for s in skus for i in locations for t in range(1, max_bins[i] + 1)),
                         cat='Binary')

    # Objective function: Minimize the distance traveled for picking and replenishment
    # Distance factors can be defined similarly to df['hi'] and df['r'], adjusted by t
    prob += lpSum(df.loc[df['s'] == s, 'hi'].values[0] * y[s, i, t] + 
                  df.loc[df['s'] == s, 'r'].values[0] * y[s, i, t] * t 
                  for s in skus for i in locations for t in range(1, max_bins[i] + 1))

    # Constraints
    # Each SKU s must be assigned to exactly one location and one bin
    for s in skus:
        prob += lpSum(y[s, i, t] for i in locations for t in range(1, max_bins[i] + 1)) == 1

    # Ensure the bin capacities are not exceeded at each location
    for i in locations:
        for t in range(1, max_bins[i] + 1):
            prob += lpSum(y[s, i, t] for s in skus) <= 1  # Assuming each bin can store one SKU

    # Solve the problem
    prob.solve()

    # Output the results
    results = []
    for s in skus:
        for i in locations:
            for t in range(1, max_bins[i] + 1):
                if y[s, i, t].value() == 1:
                    results.append({'SKU': s, 'Location': i, 'Bin': t})

    results_df = pd.DataFrame(results)
    print(results_df)

# Usage example
if __name__ == "__main__":
    optimize_warehouse_storage('Book12.csv')
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /usr/local/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/f8/sfvcnkwx62g3v6xnb7x8g7580000gn/T/b5d79c704ca04947a437bd23175f1a84-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/f8/sfvcnkwx62g3v6xnb7x8g7580000gn/T/b5d79c704ca04947a437bd23175f1a84-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 130 COLUMNS
# At line 18611 RHS
# At line 18737 BOUNDS
# At line 22434 ENDATA
# Problem MODEL has 125 rows, 3696 columns and 7392 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.01 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
#                                 SKU       Location  Bin
# 0                         Stamp Pad  Rak D Level 4    1
# 1                              Paku  Rak C Level 4    2
# 2         Pengharum Ruangan Gantung  Rak B Level 1    1
# 3                       Kertas Foto  Rak B Level 1    1
# 4                       Water Based  Rak B Level 4    4
# 5                       Water Based  Rak C Level 4    3
# 6                       Water Based  Rak A Level 4    4
# 7                   Correction Tape  Rak D Level 3    1
# 8                     HDMI Type 10M  Rak A Level 4    3
# 9                          Harddisk  Rak A Level 3    3
# 10                Kit Kabel & Remot  Rak B Level 4    1
# 11                     Lakban Merah  Rak B Level 4    2
# 12                     Lakban Merah  Rak C Level 3    3
# 13                  Isi Stappler 10  Rak E Level 2    2
# 14                  Isi Stappler 10  Rak D Level 4    2
# 15                  Pulpen Standard  Rak E Level 4    1
# 16          Spray Pengharum Ruangan  Rak B Level 2    1
# 17          Spray Pengharum Ruangan  Rak C Level 3    1
# 18                  Clip Binder 111  Rak B Level 4    3
# 19                     Stabilo Boss  Rak B Level 3    1
# 20                           Panfix  Rak B Level 2    2
# 21                           Panfix  Rak B Level 2    3
# 22            Penghapus Papan Tulis  Rak E Level 3    1
# 23                    Pulpen faster  Rak E Level 1    1
# 24                    Lem Fox Besar  Rak D Level 4    3
# 25                    Lampu Panjang  Rak A Level 4    4
# 26                         Keyboard  Rak A Level 3    3
# 27                     Spidol Warna  Rak B Level 4    1
# 28             Buku Akuntansi Kecil  Rak E Level 2    1
# 29   Buku Akuntansi Persegi Panjang  Rak C Level 3    1
# 30                     Amplop Tel-U  Rak A Level 4    4
# 31                     Amplop Tel-U  Rak E Level 4    4
# 32                     Amplop Tel-U  Rak D Level 4    4
# 33                  Magic Twist Tie  Rak D Level 3    1
# 34                     Sampul Putih  Rak D Level 4    1
# 35  Baterai Alkaline AA (Box Kecil)  Rak C Level 4    4
# 36  Baterai Alkaline AA (Box Kecil)  Rak A Level 4    4
# 37                  Clip Binder 200  Rak E Level 3    3
# 38                          Gunting  Rak A Level 4    1
# 39                           Amplop  Rak A Level 2    1
# 40                  Clip Binder 107  Rak E Level 4    3
# 41                         Pembatas  Rak E Level 4    3
# 42                   Stappler Besar  Rak C Level 1    1
# 43                 Map Office Warna  Rak A Level 4    4
# 44                 Map Office Warna  Rak D Level 4    4
# 45                       Glue Stick  Rak E Level 4    3
# 46                    Tinta Printer  Rak B Level 4    1
# 47                    Clip Binder 6  Rak E Level 4    2
# 48            Sampul Plastik Bening  Rak A Level 3    1
# 49                   Lem Fox Sedang  Rak B Level 3    2
# 50                   Lem Fox Sedang  Rak C Level 3    2
# 51                      Memory Card  Rak A Level 4    1
# 52                        Map Tel-U  Rak E Level 3    3
# 53             Baterai Alkaline AAA  Rak A Level 4    4
# 54                           Pensil  Rak D Level 3    1
# 55                    Tissue Wipers  Rak D Level 4    1
# 56                   TP Link Router  Rak E Level 4    2
# 57                  Clip Binder 155  Rak A Level 3    2
# 58         Laminating Pouch Film A4  Rak B Level 3    3
# 59                      USB Vention  Rak E Level 4    1
# 60                 Pembolong Kertas  Rak D Level 3    1

# %%
import pandas as pd
from pulp import LpMinimize, LpProblem, LpVariable, lpSum, LpBinary

def optimize_warehouse_storage(data_path, travel_time_per_unit_distance):
    pd.options.display.max_rows = None  # Display all rows
    pd.options.display.max_columns = None  # Display all columns
    pd.set_option('display.expand_frame_repr', False)  # Prevent DataFrame wrapping

    # Load and preprocess data
    df = pd.read_csv(data_path)
    
    df.sort_values('ds', ascending=False, inplace=True)

    # Extract key parameters
    skus = df['s'].unique()
    locations = df['l'].unique()
    max_bins = {location: df[df['l'] == location]['ni'].max() for location in locations}

    # Initialize the MILP problem
    prob = LpProblem("Warehouse_Optimization", LpMinimize)
    
    # Decision variables
    y = LpVariable.dicts("bin_assignment",
                         ((s, i, t) for s in skus for i in locations for t in range(1, max_bins[i] + 1)),
                         cat='Binary')

    # Objective function: Minimize the total travel time using the 'zk' column for distance
    prob += lpSum(df.loc[df['s'] == s, 'zk (m)'].values[0] * travel_time_per_unit_distance * y[s, i, t]
                  for s in skus for i in locations for t in range(1, max_bins[i] + 1))

    # Constraints: Each SKU s must be assigned to exactly one location and one bin
    for s in skus:
        prob += lpSum(y[s, i, t] for i in locations for t in range(1, max_bins[i] + 1)) == 1

    # Ensure the bin capacities are not exceeded at each location
    for i in locations:
        for t in range(1, max_bins[i] + 1):
            prob += lpSum(y[s, i, t] * df.loc[df['s'] == s, 'qs'].values[0] for s in skus) <= df.loc[df['l'] == i, 'ni'].max()

    # Solve the problem
    prob.solve()

    # Output the results
    total_distance = 0
    total_time = 0
    results = []
    for s in skus:
        for i in locations:
            for t in range(1, max_bins[i] + 1):
                if y[s, i, t].value() == 1:
                    distance = df.loc[df['s'] == s, 'zk (m)'].values[0]
                    time = distance * travel_time_per_unit_distance
                    total_distance += distance
                    total_time += time
                    results.append({'SKU': s, 'Location': i, 'Bin': t, 'Distance': distance, 'Time': time})

    results_df = pd.DataFrame(results)
    print(results_df)
    print(f"Total Distance: {total_distance} meters")
    print(f"Total Time: {total_time} time units")

# Usage example
if __name__ == "__main__":
    optimize_warehouse_storage('Book12.csv', 0.05)  # travel_time_per_unit_distance is a hypothetical value
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /usr/local/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/f8/sfvcnkwx62g3v6xnb7x8g7580000gn/T/9faef47e9a4d4c4bbc36eb420a8e1f9c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/f8/sfvcnkwx62g3v6xnb7x8g7580000gn/T/9faef47e9a4d4c4bbc36eb420a8e1f9c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 130 COLUMNS
# At line 18611 RHS
# At line 18737 BOUNDS
# At line 22434 ENDATA
# Problem MODEL has 125 rows, 3696 columns and 7392 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.04
#
#                      SKU       Location  Bin  Distance  Time
# 0  Penghapus Papan Tulis  Rak C Level 4    2       4.4  0.22
# 1         Spidol Snowman  Rak C Level 2    1       4.8  0.24
# 2           Sampul Putih  Rak C Level 4    2       4.8  0.24
# Total Distance: 14.0 meters
# Total Time: 0.7 time units

# %%
data = pd.read_csv('Book12.csv')

# %%
data.head()
# Out:
#                  s              l   hi    r    o   qk   qs   ds  ni  i (m)  zk (m)  i (detik)  zk (detik)
# 0   Spidol Snowman  Rak A Level 3  4.8  4.8  ATK  105  492  105   3    4.8     4.8        130         160
# 1   Puplen Snowman  Rak A Level 3  4.8  4.8  ATK   99  720   99   3    4.8     4.8        130         160
# 2    Pulpen faster  Rak A Level 3  4.8  4.8  ATK  105   36  105   3    4.8     4.8        130         160
# 3  Pulpen Standard  Rak A Level 3  4.8  4.8  ATK   94   36   94   3    4.8     4.8        130         160
# 4     Spidol Warna  Rak A Level 3  4.8  4.8  ATK  112   10  112   3    4.8     4.8        130         160

# %%
import pandas as pd
import numpy as np
from pulp import LpMinimize, LpProblem, LpVariable, lpSum, LpBinary

def optimize_warehouse_storage(data_path, travel_time_per_unit_distance):
    pd.options.display.max_rows = None  # Display all rows
    pd.options.display.max_columns = None  # Display all columns
    pd.set_option('display.expand_frame_repr', False)  # Prevent DataFrame wrapping

    # Load and preprocess data
    df = pd.read_csv(data_path)

    # Extract key parameters
    skus = df['s'].unique()
    locations = df['l'].unique()
    max_bins = {location: df[df['l'] == location]['ni'].max() for location in locations}

    # Initialize the MILP problem
    prob = LpProblem("Warehouse_Optimization", LpMinimize)
    
    # Decision variables
    y = LpVariable.dicts("bin_assignment",
                         ((s, i, t) for s in skus for i in locations for t in range(1, max_bins[i] + 1)),
                         cat='Binary')

    # Objective function: Minimize the total distance and time preparing orders
    prob += lpSum(df.loc[df['s'] == s, 'zk (m)'].values[0] * y[s, i, t] +
                  df.loc[df['s'] == s, 'zk (detik)'].values[0] * y[s, i, t]
                  for s in skus for i in locations for t in range(1, max_bins[i] + 1))

    # Constraints: Each SKU s must be assigned to exactly one bin in one location
    for s in skus:
        prob += lpSum(y[s, i, t] for i in locations for t in range(1, max_bins[i] + 1)) == 1

    # Ensure the bin capacities are not exceeded at each location
    for i in locations:
        for t in range(1, max_bins[i] + 1):
            prob += lpSum(y[s, i, t] for s in skus) <= 1  # Assuming each bin can store one SKU

    # Solve the problem
    prob.solve()

    # Output the results
    total_distance = 0
    total_time = 0
    results = []
    for s in skus:
        for i in locations:
            for t in range(1, max_bins[i] + 1):
                if y[s, i, t].value() == 1:
                    distance = df.loc[df['s'] == s, 'zk (m)'].values[0]
                    time = df.loc[df['s'] == s, 'zk (detik)'].values[0]
                    total_distance += distance
                    total_time += time
                    results.append({'SKU': s, 'Location': i, 'Bin': t, 'Distance': distance, 'Time': time})

    results_df = pd.DataFrame(results)
    print(results_df)
    print(f"Total Distance: {total_distance} meters")
    print(f"Total Time: {total_time} seconds")

# Usage example
if __name__ == "__main__":
    optimize_warehouse_storage('Book12.csv', 0.05)  # travel_time_per_unit_distance is a hypothetical value
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /usr/local/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/f8/sfvcnkwx62g3v6xnb7x8g7580000gn/T/b6a29d0eaacf4112a7bc33d933704089-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/f8/sfvcnkwx62g3v6xnb7x8g7580000gn/T/b6a29d0eaacf4112a7bc33d933704089-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 130 COLUMNS
# At line 18611 RHS
# At line 18737 BOUNDS
# At line 22434 ENDATA
# Problem MODEL has 125 rows, 3696 columns and 7392 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
#                                 SKU       Location  Bin  Distance  Time
# 0                    Spidol Snowman  Rak C Level 2    1       4.8   160
# 1                     Pulpen faster  Rak C Level 4    4       4.8   160
# 2                   Pulpen Standard  Rak B Level 3    1       4.8   160
# 3                      Spidol Warna  Rak B Level 4    1       4.8   160
# 4                      Sampul Putih  Rak B Level 4    3       4.8   180
# 5           Spray Pengharum Ruangan  Rak A Level 3    2       4.8   140
# 6           Spray Pengharum Ruangan  Rak E Level 3    2       4.8   140
# 7         Pengharum Ruangan Gantung  Rak B Level 1    1       4.8   140
# 8              Buku Akuntansi Besar  Rak A Level 4    1       4.8   120
# 9              Buku Akuntansi Kecil  Rak E Level 2    1       4.8   120
# 10                  Gantungan Kunci  Rak D Level 4    1       4.8   120
# 11              Correction Pen Cair  Rak A Level 4    4       4.4   170
# 12                  Correction Tape  Rak B Level 3    2       4.4   170
# 13                           Pensil  Rak D Level 3    1       4.4   170
# 14                     Stabilo Boss  Rak D Level 3    3       4.4   170
# 15                           Amplop  Rak E Level 3    2       4.4   170
# 16            Penghapus Papan Tulis  Rak A Level 1    1       4.4   170
# 17            Penghapus Papan Tulis  Rak E Level 2    1       4.4   170
# 18                    Tinta Printer  Rak B Level 3    3       4.4   150
# 19                  Stappler Sedang  Rak C Level 3    2       4.4   150
# 20              Refill Tinta Spidol  Rak E Level 2    2       4.4   150
# 21                   Tape Dispenser  Rak B Level 2    3       4.4   150
# 22                 Pembolong Kertas  Rak E Level 3    3       4.4   150
# 23                        Buku Note  Rak D Level 4    2       4.4   150
# 24                      Memory Card  Rak E Level 3    2       4.4   130
# 25                  Magic Twist Tie  Rak E Level 3    3       4.4   130
# 26                        Stamp Pad  Rak C Level 1    1       4.4   130
# 27                      Sticky Note  Rak B Level 2    2       4.4   130
# 28                              RAM  Rak A Level 3    3       4.4   130
# 29                      Kertas Foto  Rak B Level 1    1       4.4   110
# 30                    Tissue Wipers  Rak B Level 2    2       4.4   110
# 31                     Map Business  Rak A Level 3    2       4.0   160
# 32                   Lem Fox Sedang  Rak E Level 4    1       4.0   160
# 33                          Lem Uhu  Rak A Level 2    2       4.0   160
# 34                       Glue Stick  Rak E Level 4    3       4.0   160
# 35                    Lem Fox Besar  Rak B Level 3    2       4.0   160
# 36                    Clip Binder 6  Rak E Level 4    2       4.0   140
# 37                  Clip Binder 200  Rak A Level 3    3       4.0   140
# 38                  Clip Binder 111  Rak B Level 4    3       4.0   140
# 39                  Clip Binder 107  Rak A Level 2    1       4.0   140
# 40                       USB Type C  Rak C Level 2    2       4.0   100
# 41                  Isi Stappler 10  Rak B Level 1    1       4.0   140
# 42                   Isi Stappler 3  Rak B Level 1    1       4.0   140
# 43                   Isi Stappler 3  Rak E Level 1    1       4.0   140
# 44                     Lakban Hitam  Rak B Level 4    4       4.0   120
# 45                     Lakban Hitam  Rak C Level 4    1       4.0   120
# 46                     Lakban Hitam  Rak C Level 4    2       4.0   120
# 47                     Lakban Putih  Rak B Level 2    1       4.0   120
# 48                     Lakban Putih  Rak B Level 1    1       4.0   120
# 49                     Lakban Merah  Rak B Level 4    2       4.0   120
# 50                     Lakban Merah  Rak C Level 3    3       4.0   120
# 51                   Lakban Cokelat  Rak E Level 3    2       4.0   120
# 52                           Panfix  Rak A Level 3    1       4.0   120
# 53                HDMI Card Vention  Rak C Level 3    1       4.0   100
# 54                             Paku  Rak C Level 4    2       4.0   100
# 55                         Pembatas  Rak A Level 2    1       3.6   150
# 56                         Keyboard  Rak D Level 3    2       3.6   130
# 57             Baterai Alkaline AAA  Rak A Level 2    1       3.2   130
# 58  Baterai Alkaline AA (Box Kecil)  Rak A Level 4    3       3.2   130
# 59                     Power Supply  Rak D Level 4    3       3.2   130
# 60                 Map Office Warna  Rak D Level 4    1       3.2   120
# Total Distance: 256.8 meters
# Total Time: 8510 seconds

# %%
import pandas as pd
import numpy as np
from pulp import LpMinimize, LpProblem, LpVariable, lpSum, LpBinary

def optimize_warehouse_storage(data_path, travel_time_per_unit_distance):
    pd.options.display.max_rows = None  # Display all rows
    pd.options.display.max_columns = None  # Display all columns
    pd.set_option('display.expand_frame_repr', False)  # Prevent DataFrame wrapping

    # Load and preprocess data
    df = pd.read_csv(data_path)

    # Extract key parameters
    skus = df['s'].unique()
    locations = df['l'].unique()
    max_bins = {location: df[df['l'] == location]['ni'].max() for location in locations}

    # Initialize the MILP problem
    prob = LpProblem("Warehouse_Optimization", LpMinimize)
    
    # Decision variables
    y = LpVariable.dicts("bin_assignment",
                         ((s, i, t) for s in skus for i in locations for t in range(1, max_bins[i] + 1)),
                         cat='Binary')

    # Objective function: Minimize the total travel time and distance
    prob += lpSum(df.loc[df['s'] == s, 'zk (m)'].values[0] * travel_time_per_unit_distance * y[s, i, t] +
                  df.loc[df['s'] == s, 'i (m)'].values[0] * travel_time_per_unit_distance * y[s, i, t]
                  for s in skus for i in locations for t in range(1, max_bins[i] + 1))

    # Constraints: Each SKU s must be assigned to exactly one location and one bin
    for s in skus:
        prob += lpSum(y[s, i, t] for i in locations for t in range(1, max_bins[i] + 1)) == 1

    # Ensure the bin capacities are not exceeded at each location
    for i in locations:
        for t in range(1, max_bins[i] + 1):
            prob += lpSum(y[s, i, t] for s in skus) <= 1  # Assuming each bin can store one SKU

    # Solve the problem
    prob.solve()

    # Output the results
    total_distance = 0
    total_time = 0
    results = []
    for s in skus:
        for i in locations:
            for t in range(1, max_bins[i] + 1):
                if y[s, i, t].value() == 1:
                    distance_zk = df.loc[df['s'] == s, 'zk (m)'].values[0]
                    time_zk = df.loc[df['s'] == s, 'zk (detik)'].values[0]
                    distance_i = df.loc[df['s'] == s, 'i (m)'].values[0]
                    time_i = df.loc[df['s'] == s, 'i (detik)'].values[0]
                    total_distance += distance_zk + distance_i
                    total_time += time_zk + time_i
                    results.append({'SKU': s, 'Location': i, 'Bin': t, 'Distance zk': distance_zk, 'Time zk': time_zk, 'Distance i': distance_i, 'Time i': time_i})

    results_df = pd.DataFrame(results)
    print(results_df)
    print(f"Total Distance: {total_distance} meters")
    print(f"Total Time: {total_time} seconds")

# Usage example
if __name__ == "__main__":
    optimize_warehouse_storage('Book12.csv', 1)  # travel_time_per_unit_distance is a hypothetical value
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /usr/local/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/f8/sfvcnkwx62g3v6xnb7x8g7580000gn/T/bae0d42c1dcf4cd99c525b33b671cb6d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/f8/sfvcnkwx62g3v6xnb7x8g7580000gn/T/bae0d42c1dcf4cd99c525b33b671cb6d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 130 COLUMNS
# At line 18611 RHS
# At line 18737 BOUNDS
# At line 22434 ENDATA
# Problem MODEL has 125 rows, 3696 columns and 7392 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
#                                 SKU       Location  Bin  Distance zk  Time zk  Distance i  Time i
# 0                    Spidol Snowman  Rak C Level 3    3          4.8      160         4.8     130
# 1                    Puplen Snowman  Rak B Level 4    3          4.8      160         4.8     130
# 2                     Pulpen faster  Rak C Level 4    4          4.8      160         4.8     130
# 3                   Pulpen Standard  Rak B Level 3    1          4.8      160         4.8     130
# 4                      Spidol Warna  Rak B Level 4    1          4.8      160         4.8     130
# 5             Sampul Plastik Bening  Rak A Level 3    1          4.8      180         4.8     140
# 6           Spray Pengharum Ruangan  Rak A Level 3    2          4.8      140         4.8     120
# 7           Spray Pengharum Ruangan  Rak C Level 4    2          4.8      140         4.8     120
# 8         Pengharum Ruangan Gantung  Rak A Level 2    2          4.8      140         4.8     120
# 9                 Kit Kabel & Remot  Rak B Level 4    1          4.8      120         4.8     110
# 10             Buku Akuntansi Besar  Rak A Level 4    1          4.8      120         4.8     110
# 11             Buku Akuntansi Kecil  Rak E Level 2    1          4.8      120         4.8     110
# 12   Buku Akuntansi Persegi Panjang  Rak D Level 4    4          4.8      120         4.8     110
# 13                  Gantungan Kunci  Rak E Level 3    3          4.8      120         4.8     110
# 14              Correction Pen Cair  Rak A Level 4    4          4.4      170         4.4     130
# 15                  Correction Tape  Rak B Level 3    2          4.4      170         4.4     130
# 16                           Pensil  Rak D Level 3    1          4.4      170         4.4     130
# 17                     Stabilo Boss  Rak D Level 3    3          4.4      170         4.4     130
# 18            Penghapus Papan Tulis  Rak A Level 1    1          4.4      170         4.4     130
# 19                   Stappler Besar  Rak C Level 4    3          4.4      150         4.4     120
# 20                  Stappler Sedang  Rak C Level 3    2          4.4      150         4.4     120
# 21              Refill Tinta Spidol  Rak E Level 2    2          4.4      150         4.4     120
# 22                   Tape Dispenser  Rak B Level 2    3          4.4      150         4.4     120
# 23                 Pembolong Kertas  Rak E Level 3    3          4.4      150         4.4     120
# 24                        Buku Note  Rak D Level 4    2          4.4      150         4.4     120
# 25                      Memory Card  Rak B Level 4    2          4.4      130         4.4     110
# 26                  Magic Twist Tie  Rak E Level 3    3          4.4      130         4.4     110
# 27                        Stamp Pad  Rak E Level 3    1          4.4      130         4.4     110
# 28                      Sticky Note  Rak B Level 2    2          4.4      130         4.4     110
# 29                              RAM  Rak A Level 3    3          4.4      130         4.4     110
# 30                      Kertas Foto  Rak D Level 4    2          4.4      110         4.4     100
# 31                      Kertas Foto  Rak E Level 4    2          4.4      110         4.4     100
# 32                    Tissue Wipers  Rak B Level 3    2          4.4      110         4.4     100
# 33                     Map Business  Rak D Level 3    3          4.0      160         4.0     120
# 34                       Glue Stick  Rak D Level 3    1          4.0      160         4.0     120
# 35                    Lem Fox Besar  Rak B Level 3    2          4.0      160         4.0     120
# 36                    Clip Binder 6  Rak E Level 4    2          4.0      140         4.0     110
# 37                  Isi Stappler 10  Rak B Level 1    1          4.0      140         4.0     110
# 38                   Isi Stappler 3  Rak E Level 4    4          4.0      140         4.0     110
# 39                   Isi Stappler 3  Rak E Level 1    1          4.0      140         4.0     110
# 40                        Mouse Pad  Rak B Level 1    1          4.0      120         4.0     110
# 41                        Mouse Pad  Rak C Level 4    1          4.0      120         4.0     110
# 42                     Lakban Putih  Rak A Level 4    2          4.0      120         4.0     100
# 43                     Lakban Merah  Rak B Level 3    2          4.0      120         4.0     100
# 44                    Lakban Kuning  Rak C Level 4    4          4.0      120         4.0     100
# 45                           Panfix  Rak A Level 3    1          4.0      120         4.0     100
# 46                HDMI Card Vention  Rak A Level 4    4          4.0      100         4.0      90
# 47                   TP Link Router  Rak B Level 2    1          4.0      100         4.0      90
# 48                        Map Tel-U  Rak A Level 4    2          3.6      150         3.6     110
# 49                         Keyboard  Rak D Level 3    2          3.6      130         3.6     100
# 50                         Harddisk  Rak A Level 4    1          3.6      130         3.6     100
# 51                         Harddisk  Rak E Level 3    2          3.6      130         3.6     100
# 52  Baterai Alkaline AA (Box Besar)  Rak A Level 4    2          3.2      130         3.2     100
# 53             Baterai Alkaline AAA  Rak A Level 2    1          3.2      130         3.2     100
# 54  Baterai Alkaline AA (Box Kecil)  Rak A Level 4    3          3.2      130         3.2     100
# 55  Baterai Alkaline AA (Box Kecil)  Rak B Level 3    2          3.2      130         3.2     100
# 56                     Power Supply  Rak A Level 4    4          3.2      130         3.2     100
# 57                     Power Supply  Rak D Level 4    3          3.2      130         3.2     100
# 58                     Power Supply  Rak D Level 4    4          3.2      130         3.2     100
# 59                     Amplop Tel-U  Rak E Level 4    1          3.2      120         3.2      90
# 60                     Amplop Tel-U  Rak E Level 4    3          3.2      120         3.2      90
# 61                 Map Office Warna  Rak D Level 4    1          3.2      120         3.2      90
# 62                      Water Based  Rak C Level 2    1          3.2       80         3.2      70
# 63                      Water Based  Rak E Level 2    1          3.2       80         3.2      70
# Total Distance: 527.1999999999999 meters
# Total Time: 15700 seconds
